# %%
import os
import multiprocess
import pickle

import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

from utils import get_object_names_from_code

# %%
df = pd.concat(
        [pd.read_csv(f"generated/{file}") for file in os.listdir("generated")]
    ).reset_index(drop=True)

df["sample_type"] = None
df["initial_test_case"] = None
df["initial_output"] = None

df.loc[df["coverage"] > 99, "sample_type"] = 1

df
# Out:
#                                            original_code  \
# 0      def quaternion_multiply(r, q):\r\n    \r\n    ...
# 1      def sing_three(mu, c, i0=1.0):\r\n    \r\n    ...
# 2      def get_rgb_from_int(rgb_int):\r\n    \r\n    ...
# 3      def inflate(tensor, times, dim):\r\n    \r\n  ...
# 4      def radii(mag):\r\n    \r\n    # ADM mask all ...
# ...                                                  ...
# 76915  def recursiveChoosing ( arr , start , M , dp )...
# 76916  def findSmallest ( arr , n ) :\n    res = 1\n ...
# 76917  \nmanufacturer = "Dell"\nscreen_size = 15.6\np...
# 76918  \nimport random\ndata = [1, 2, 3, 4, 5]\n# ran...
# 76919  def findSum ( n ) :\n    sum = 0\n    i = 1\n ...
#
#                                              pytest_code  coverage  \
# 0      # test_source.py\r\nimport pytest\r\nimport so...     100.0
# 1      import pytest\r\nfrom source import sing_three...     100.0
# 2      import pytest\r\nimport sys\r\nsys.path.insert...     100.0
# 3      # test_source.py\r\nimport pytest\r\nfrom sour...     100.0
# 4      # test_source.py\r\nimport pytest\r\nimport sy...     100.0
# ...                                                  ...       ...
# 76915  import pytest\n\ndef test_recursive_choosing()...       0.0
# 76916  from source import *\nimport pytest\n\ndef tes...       0.0
# 76917  import pytest\nfrom source import manufacturer...       0.0
# 76918  import pytest\nfrom source import *\ndef test_...       0.0
# 76919  import pytest\nfrom source import findSum\n\nd...       0.0
#
#       sample_type initial_test_case initial_output
# 0               1              None           None
# 1               1              None           None
# 2               1              None           None
# 3               1              None           None
# 4               1              None           None
# ...           ...               ...            ...
# 76915        None              None           None
# 76916        None              None           None
# 76917        None              None           None
# 76918        None              None           None
# 76919        None              None           None
#
# [76920 rows x 6 columns]

# %%
def get_all_combinations_wrapper(test_params):
    from utils import timeout
    @timeout(30)
    def get_all_combinations(test_params):
        from itertools import combinations
        from utils import run_pytest, delete_object_from_code

        code, pytest_code, coverage, test_functions = test_params
        
        k = min(len(test_functions) - 1, 5)


        for combination in combinations(test_functions, k):
            try:
                cnt_test = pytest_code
                for obj in combination:
                    cnt_test = delete_object_from_code(obj, cnt_test)
                    
                res = run_pytest(code, cnt_test)

                if (not res["failed_assertions"]) and\
                        (res["stderr"] == "") and\
                        (0 < res["coverage"] < 100): 
                    return (code, pytest_code, res["coverage"], 2, cnt_test)

            except Exception as e:
                continue
    
    try:
        return get_all_combinations(test_params)
    except:
        return None, None, None, None, None

# %% [markdown]
# ### Make and append incomplete test files

# %%
def extract_test_functions(x):
    try:
        funcs = get_object_names_from_code(x)
    except:
        return []
    test_funcs = [i for i in funcs if i.startswith("test_")]
    return test_funcs


df_map = df[df["sample_type"] == 1][["original_code", "pytest_code", "coverage"]]
df_map["test_funcs"] = df_map["pytest_code"].map(extract_test_functions)
df_map = df_map[df_map.test_funcs.map(len) > 1]
df_map
# Out:
#                                            original_code  \
# 4      def radii(mag):\r\n    \r\n    # ADM mask all ...
# 8      def axisAligned(angle, tol=None, axis=None):\r...
# 11     def dms(degrees):\r\n    \r\n\r\n    degrees_i...
# 15     def constrain(value, min_value, max_value):\r\...
# 20     def denormalize_bbox(bbox, rows, cols):\r\n   ...
# ...                                                  ...
# 66081  \ndef calculate_power(base, exponent):\n    ""...
# 66082  \nimport math\n\ndef calculate_hypotenuse(a, b...
# 66083  import math\ndef getSum ( a , n ) :\n    sum =...
# 66084  def digitWell ( n , m , k ) :\n    cnt = 0\n  ...
# 66085  \ndef find_missing_number(numbers):\n    """\n...
#
#                                              pytest_code  coverage  \
# 4      # test_source.py\r\nimport pytest\r\nimport sy...     100.0
# 8      import pytest\r\nfrom source import axisAligne...     100.0
# 11     import source\r\n\r\ndef test_dms_positive_deg...     100.0
# 15     # test_source.py\r\nimport pytest\r\nfrom sour...     100.0
# 20     # test_source.py\r\n\r\nimport pytest\r\nfrom ...     100.0
# ...                                                  ...       ...
# 66081  from source import calculate_power\nimport pyt...     100.0
# 66082  import pytest\nfrom source import calculate_hy...     100.0
# 66083  import pytest\nfrom source import *\n\ndef tes...     100.0
# 66084  import pytest\nfrom source import digitWell, f...     100.0
# 66085  import pytest\nfrom source import find_missing...     100.0
#
#                                               test_funcs
# 4      [test_radii_input_greater_than_12, test_radii_...
# 8      [test_axisAligned_horizontal, test_axisAligned...
# 11     [test_dms_negative_degrees, test_dms_positive_...
# 15     [test_constrain_normal, test_constrain_max, te...
# 20     [test_denormalize_bbox_positive, test_denormal...
# ...                                                  ...
# 66081  [test_calculate_power_float, test_calculate_po...
# 66082  [test_calculate_hypotenuse, test_calculate_hyp...
# 66083                    [test_getSum_zero, test_getSum]
# 66084                     [test_findInt, test_digitWell]
# 66085  [test_find_missing_number, test_find_missing_n...
#
# [14052 rows x 4 columns]

# %%
df_map = df_map.loc[df_map.test_funcs.map(len).sort_values().index].reset_index(drop=True)
df_map
# Out:
#                                            original_code  \
# 0      \ndef find_missing_number(numbers):\n    """\n...
# 1      def convert_retention_to_seconds(desired_reten...
# 2      \ndef bubble_sort(arr):\n    n = len(arr)\n   ...
# 3      def brokenTen(value):\n    \n    if (value < 1...
# 4      \ndef is_prime(n):\n    if n < 2:\n        ret...
# ...                                                  ...
# 14047  for i in range(10):\n    for j in range(10):\n...
# 14048  def convertor(value, fromunits, tounits):\n   ...
# 14049  def count_set_bits(n, k):\n  \n  count = 0\n  ...
# 14050  def get_def_class(word):\r\n    \r\n    test_t...
# 14051  a = '''YES\nNO\nNO\nYES\nNO\nNO\nNO\nNO\nNO\nY...
#
#                                              pytest_code  coverage  \
# 0      import pytest\nfrom source import find_missing...     100.0
# 1      import sys\nsys.path.append(".") # this is to ...     100.0
# 2      import pytest\nfrom source import bubble_sort\...     100.0
# 3      #test_source.py\nimport pytest\nfrom source im...     100.0
# 4      import pytest\nfrom source import is_prime, su...     100.0
# ...                                                  ...       ...
# 14047  import pytest\nfrom source import i, j\ndef te...     100.0
# 14048  import pytest\nimport sys\nsys.path.append('.'...     100.0
# 14049  import pytest\nfrom source import count_set_bi...     100.0
# 14050  import pytest\r\nimport source\r\n\r\ndef test...     100.0
# 14051  import pytest\n@pytest.fixture()\ndef source()...     100.0
#
#                                               test_funcs
# 0      [test_find_missing_number, test_find_missing_n...
# 1      [test_convert_retention_to_seconds_hours, test...
# 2                 [test_bubble_sort_2, test_bubble_sort]
# 3      [test_brokenTen_greater_than_ten, test_brokenT...
# 4                    [test_is_prime, test_sum_of_primes]
# ...                                                  ...
# 14047  [test_twenty_four, test_five, test_thirteen, t...
# 14048  [test_wavenumber_to_eV, test_eV_to_hartree, te...
# 14049  [test_count_set_bits_13, test_count_set_bits_2...
# 14050  [test_get_def_class_burned, test_get_def_class...
# 14051  [test_a17, test_a63, test_a46, test_a92, test_...
#
# [14052 rows x 4 columns]

# %%
step_size = 300
for i in range(0, df_map.shape[0], step_size):
    cnt_df_map = df_map.iloc[i : min(i + step_size, df_map.shape[0])]
    num_tasks = cnt_df_map.shape[0]

    with multiprocess.Pool(24) as pool:
        results_cov = list(tqdm(pool.imap(get_all_combinations_wrapper, cnt_df_map.to_numpy().tolist()), total=num_tasks))

    with open(f"test_completion_results/{i}_{min(i + step_size, df_map.shape[0])}_res.pkl", "wb") as f:
        pickle.dump(results_cov, f)
# Out:
#   0%|          | 0/300 [00:00<?, ?it/s]

# %%
generated = []
for file in os.listdir("test_completion_results"):
    with open(f"test_completion_results/{file}", "rb") as f:
        generated += pickle.load(f)

generated = [sample for sample in generated if sample is not None]

# %%
df = pd.DataFrame(generated)
df.columns = ["original_code", "pytest_code", "coverage", "sample_type", "initial_test_case"]
df = df.dropna(how="all").reset_index(drop=True)
df
# Out:
#                                           original_code  \
# 0     def convert_retention_to_seconds(desired_reten...
# 1     def brokenTen(value):\n    \n    if (value < 1...
# 2     \ndef is_prime(n):\n    if n < 2:\n        ret...
# 3     def call_activation(x, foo=None):\n    \n    i...
# 4     def mode(prediction, pad='[PAD]'):\n    \n    ...
# ...                                                 ...
# 5233  \nimport calendar\n\ndef get_weekdays_in_month...
# 5234  def matrix2vec(m, axis='x'):\r\n    \r\n    if...
# 5235  def compute_resize_scale(image_shape, min_side...
# 5236  \ndef fibonacci(n):\n    if n <= 0:\n        r...
# 5237  def scale_to_internal(vec, scaling_factor, sca...
#
#                                             pytest_code  coverage  \
# 0     import sys\nsys.path.append(".") # this is to ...      86.0
# 1     #test_source.py\nimport pytest\nfrom source im...      75.0
# 2     import pytest\nfrom source import is_prime, su...      93.0
# 3     import pytest\nimport sys\nsys.path.append(".....      75.0
# 4     # test_source.py\nimport sys\nsys.path.append(...      75.0
# ...                                                 ...       ...
# 5233  import pytest\nfrom source import get_weekdays...      91.0
# 5234  import pytest\r\nimport numpy as np\r\nimport ...      67.0
# 5235  import pytest\r\nimport os\r\nimport source\r\...      88.0
# 5236  import pytest\nfrom source import fibonacci\n\...      82.0
# 5237  import pytest\r\nimport sys\r\nsys.path.append...      50.0
#
#       sample_type                                  initial_test_case
# 0             2.0  import sys\nsys.path.append('.')\nfrom source ...
# 1             2.0  import pytest\nfrom source import brokenTen\n\...
# 2             2.0  import pytest\nfrom source import is_prime, su...
# 3             2.0  import pytest\nimport sys\nsys.path.append('.....
# 4             2.0  import sys\nsys.path.append('..')\nfrom source...
# ...           ...                                                ...
# 5233          2.0  import pytest\nfrom source import get_weekdays...
# 5234          2.0  import pytest\nimport numpy as np\nimport sour...
# 5235          2.0  import pytest\nimport os\nimport source\n\ndef...
# 5236          2.0  import pytest\nfrom source import fibonacci\n\...
# 5237          2.0  import pytest\nimport sys\nsys.path.append('.....
#
# [5238 rows x 5 columns]

# %%
df.to_csv("generated/incomplete_samples.csv", index=False)
