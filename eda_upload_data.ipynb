# %%
import os
import numpy as np
import pandas as pd

# %%
all = pd.concat(
    [pd.read_csv(f"generated/{file}") for file in os.listdir("generated")]
    ).reset_index(drop=True)
all[all.coverage > 99].reset_index(drop=True)
# Out:
#                                            original_code  \
# 0      def quaternion_multiply(r, q):\r\n    \r\n    ...
# 1      def sing_three(mu, c, i0=1.0):\r\n    \r\n    ...
# 2      def get_rgb_from_int(rgb_int):\r\n    \r\n    ...
# 3      def inflate(tensor, times, dim):\r\n    \r\n  ...
# 4      def radii(mag):\r\n    \r\n    # ADM mask all ...
# ...                                                  ...
# 35020  def tdoas2taus(tdoas):\r\n    \r\n\r\n    n_pa...
# 35021  def determine_num_ranges(N, max_n):\r\n       ...
# 35022  import torch\r\n\r\ndef logits_to_label(logits...
# 35023  def left_to_right_check(input_line: str, pivot...
# 35024  import torch\r\n\r\ndef compute_polar_angle(xy...
#
#                                              pytest_code  coverage
# 0      # test_source.py\r\nimport pytest\r\nimport so...     100.0
# 1      import pytest\r\nfrom source import sing_three...     100.0
# 2      import pytest\r\nimport sys\r\nsys.path.insert...     100.0
# 3      # test_source.py\r\nimport pytest\r\nfrom sour...     100.0
# 4      # test_source.py\r\nimport pytest\r\nimport sy...     100.0
# ...                                                  ...       ...
# 35020  import pytest\r\nimport numpy as np\r\nimport ...     100.0
# 35021  from source import determine_num_ranges  # ass...     100.0
# 35022  import torch\r\nimport pytest\r\nfrom source i...     100.0
# 35023  import pytest\r\nimport os\r\nimport sys\r\nsy...     100.0
# 35024  import pytest\r\nimport torch\r\nfrom source i...     100.0
#
# [35025 rows x 3 columns]

# %%
print(all.iloc[33221, 1])
# Out:
# import torch
# import pytest
#
# # Import the source file
# from source import norm_intensity
#
# # Define a range of tests
# @pytest.mark.parametrize(
#     "input,max_val,expected",
#     [
#         (torch.tensor([1, 2, 3, 4]), None, torch.tensor([0, 0.25, 0.5, 0.75])),
#         (torch.tensor([1, 1, 1, 1]), None, torch.tensor([0, 0, 0, 0])),
#         (torch.tensor([1, 2, 3, 4]), 2, torch.tensor([0, 0.5, 0.3333333333333333, 0.25])),
#     ],
# )
#
# def test_norm_intensity(input, max_val, expected):
#     """
#     This function tests the norm_intensity function
#     """
#     result = norm_intensity(input, max_val)
#     assert torch.allclose(result, expected, atol=1e-6), f"{result} != {expected}"
